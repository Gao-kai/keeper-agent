# %%
from time import time

import torch

print(f"是否支持GPU:{torch.cuda.is_available()}")
print(f"设备名:{torch.cuda.get_device_name()}")

# %% [markdown]
# ### 测试time

# %%
import time

t1 = time.time()
time.sleep(2)
t2 = time.time()
print(t2 - t1)
# Out:
# 2.0052762031555176
