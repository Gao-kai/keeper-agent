# %%
from time import time

import torch

print(f"是否支持GPU:{torch.cuda.is_available()}")
print(f"设备名:{torch.cuda.get_device_name()}")

# %% [markdown]
# ## 测试time

# %%
import time

t1 = time.time()
time.sleep(2)
t2 = time.time()
print(t2 - t1)
# Out:
# 2.0052762031555176

# %% [markdown]
# ## 测试markdown文件读取

# %%
with open("/Users/artest/Desktop/shopkeeper/knowledge/test/test.md",'r',encoding="utf-8") as file:
	content = file.read()
line_list  = content.replace('\n\n',"\n").split("\n")
print(line_list)

# 所以说第一行扫描到是header 此时body为空 current_title也为空 不触发append
# 扫码一些文字
# 遍历到2标题 其实是为前一个大包 current title是一级标题 body是收集者 父标题 一级标题没有父标题
# 收集2标题的儿子
# 遍历到2标题 为钱一个2大包 current title是一级标题 body是收集者 父标题 一级标题 list[1] = "xxx"
# 收集2‘的儿子
# 遍历到3
# Out:
# ['# 掌柜问数 —— 项目全景', '> 本文档为 Knowledge 知识库系统的全景概览课件，涵盖项目定位、系统架构、核心技术原理、目录结构、快速开始指南、数据处理流程及前后端交互等内容。', '---', '## 1. 项目概述', '### 1.1 项目定位与目标', '**项目定位：**', '掌柜问数是一个企业级智能知识库系统，结合了 **RAG（检索增强生成）** 和 **知识图谱** 技术，旨在为垂直领域（如电子产品手册、维修指南、技术文档等）提供精准、智能的知识检索与问答服务。', '', '**核心目标：**', '- 将非结构化文档（PDF、Markdown）转化为可检索的结构化知识', '- 通过多路召回策略提升检索准确率', '- 利用知识图谱实现实体关系推理', '- 提供流畅的流式问答交互体验']

# %%
print([""] * 7)
# Out:
# ['', '', '', '', '', '', '']
